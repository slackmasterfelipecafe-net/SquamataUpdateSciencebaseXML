# %% [markdown]
# # Squamata Batch Update ScienceBase XML
# A Jupyter Notebook used to download multiple XML Metadata files from ScicenceBase, make a change to this XML file and re-upload.
#
# Uses code examples found in autoSB.py, https://github.com/pbrown-usgs/science-base-automationMT/blob/first-branch/autoSB.py
#
# **Version 1.0**
#  - Change one item in a single metadata file possible
#  - Plans for new versions include adding a list for batch updates

# %%
# Load required Libraries
import sys
import os
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import json
import sys
import sciencebasepy as pysb

#Create Function that allows one to implement markdown display when printing
from IPython.display import Markdown, display
def printmd(string):
    display(Markdown(string))

# %%
#Login to ScienceBase
sb = pysb.SbSession()
username = input("Username:  ")
sb.loginc(str(username))

#Check to see if login is successful
sb.is_logged_in()

#Get the ScienceBase Login session info
sb.get_session_info()
# Out:
# Username:  pbrown@usgs.gov
# ········
# {'fullDisplayName': 'Philip J Brown II [pbrown@usgs.gov]',
#  'isLoggedIn': True,
#  'jossoSessionId': '9D57EB13DE7CC67B1841F36293024014',
#  'displayName': 'Philip J Brown II',
#  'email': 'pbrown@usgs.gov',
#  'username': 'pbrown@usgs.gov'}

# %%
# Now lets get the item - be sure to use the correct catalog number!!! 5f2b00f782ceae4cb3c09708
#catNum = '5f066e2682ce21d4c3f90237' #Akansas
catNum = '5f2b00f782ceae4cb3c09708' #Loma San Andreas MT
item_json = sb.get_item(catNum)

#print ("Public Item: \n\t" + str(item_json))
print(json.dumps(item_json, indent=2, sort_keys=True))
# Out:
# {
#   "body": "The U.S. Geological Survey (USGS) Geology, Geophysics and Geochemistry Science Center (GGGSC) collaborated with the USGS Science Analytics and Synthesis (SAS) team to preserve and release a subset of magnetotelluric data from the San Andreas Fault in Loma Prieta, California. The San Andreas Fault data were collected by the Branch of Geophysics, a precursor to the now GGGSC, between 1989 and 1994. The magnetotelluric data selected for this preservation project were collected in 1989 using USGS portable truck mounted systems that measure the distribution of electrical conductivity beneath the surface of the earth. Truck mounted systems of this era output data to 3.5\u201d discs, from which data were recovered and transformed to binary or ASCII formats using proprietary software. This USGS data release includes the original binary and ASCII data files and derivative EDI files (Wight, 1988), a common modern format for magnetotelluric modelling, created using Python-based software developed by the SAS team. (Wight, D.E., 1988, MT/EMAP Data Interchange Standard, Technical standards committee report, Society of Exploration Geophysicists, isbn=9780931830617, http://www.seg.org/documents/10161/77915/seg_mt_emap_1987.pdf.)",
#   "browseCategories": [
#     "Data"
#   ],
#   "browseTypes": [
#     "Shapefile",
#     "Downloadable",
#     "Map Service",
#     "OGC WMS Layer",
#     "OGC WFS Layer"
#   ],
#   "citation": "Rodriguez, B.D., Johnson, M.R., McClees-Funinan, R., Powell, S., and Enns, K,D., 2020, Magnetotelluric Data from the San Andreas Fault, Loma Prieta CA, 1989: U.S. Geological Survey data release, https://doi.org/10.5066/P9DIJHDK.",
#   "contacts": [
#     {
#       "contactType": "person",
#       "email": "brod@usgs.gov",
#       "jobTitle": "Geophysicist",
#       "name": "Brian D Rodriguez",
#       "organization": {
#         "displayText": "U.S. Geological Survey, Southwest Region"
#       },
#       "primaryLocation": {
#         "faxPhone": "303-236-1425",
#         "mailAddress": {
#           "city": "Lakewood",
#           "country": "United States",
#           "line1": "Mail Stop 964, W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         },
#         "officePhone": "303-236-1361",
#         "streetAddress": {}
#       },
#       "type": "Point of Contact"
#     },
#     {
#       "contactType": "organization",
#       "email": "brod@usgs.gov",
#       "jobTitle": "Geophysicist",
#       "name": "U.S. Geological Survey, Southwest Region",
#       "organization": {},
#       "primaryLocation": {
#         "faxPhone": "303-236-1425",
#         "mailAddress": {
#           "city": "Lakewood",
#           "country": "United States",
#           "line1": "Mail Stop 964, W 6th Ave Kipling St",
#           "state": "CO",
#           "zip": "80225"
#         },
#         "officePhone": "303-236-1361",
#         "streetAddress": {}
#       },
#       "type": "Point of Contact"
#     },
#     {
#       "name": "Brian D. Rodriguez",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "streetAddress": {}
#       },
#       "type": "Originator"
#     },
#     {
#       "name": "Michaela R. Johnson",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "streetAddress": {}
#       },
#       "type": "Originator"
#     },
#     {
#       "name": "Ricardo McClees-Funinan",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "streetAddress": {}
#       },
#       "type": "Originator"
#     },
#     {
#       "name": "Shafer Powell",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "streetAddress": {}
#       },
#       "type": "Originator"
#     },
#     {
#       "name": "Kyle D. Enns",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {},
#         "streetAddress": {}
#       },
#       "type": "Originator"
#     },
#     {
#       "contactType": "person",
#       "email": "shaferpowell@gmail.com",
#       "jobTitle": "Technical Support",
#       "name": "Shafer Powell",
#       "organization": {
#         "displayText": "U.S. Geological Survey, SOUTHWEST REGION"
#       },
#       "primaryLocation": {
#         "mailAddress": {
#           "city": "Knoxville",
#           "country": "US",
#           "line1": "312 E Woodland Ave",
#           "state": "TN",
#           "zip": "37917"
#         },
#         "officePhone": "865-307-3339",
#         "streetAddress": {}
#       },
#       "type": "Metadata Contact"
#     },
#     {
#       "contactType": "organization",
#       "email": "shaferpowell@gmail.com",
#       "jobTitle": "Technical Support",
#       "name": "U.S. Geological Survey, SOUTHWEST REGION",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {
#           "city": "Knoxville",
#           "country": "US",
#           "line1": "312 E Woodland Ave",
#           "state": "TN",
#           "zip": "37917"
#         },
#         "officePhone": "865-307-3339",
#         "streetAddress": {}
#       },
#       "type": "Metadata Contact"
#     },
#     {
#       "contactType": "person",
#       "email": "sciencebase@usgs.gov",
#       "name": "GS ScienceBase",
#       "organization": {
#         "displayText": "U.S. Geological Survey"
#       },
#       "primaryLocation": {
#         "mailAddress": {
#           "city": "Denver",
#           "country": "United States",
#           "line1": "Denver Federal Center, Building 810, Mail Stop 302",
#           "state": "CO",
#           "zip": "80225"
#         },
#         "officePhone": "1-888-275-8747",
#         "streetAddress": {}
#       },
#       "type": "Distributor"
#     },
#     {
#       "contactType": "organization",
#       "email": "sciencebase@usgs.gov",
#       "name": "U.S. Geological Survey",
#       "organization": {},
#       "primaryLocation": {
#         "mailAddress": {
#           "city": "Denver",
#           "country": "United States",
#           "line1": "Denver Federal Center, Building 810, Mail Stop 302",
#           "state": "CO",
#           "zip": "80225"
#         },
#         "officePhone": "1-888-275-8747",
#         "streetAddress": {}
#       },
#       "type": "Distributor"
#     }
#   ],
#   "dates": [
#     {
#       "dateString": "2020",
#       "label": "Publication Date",
#       "type": "Publication"
#     },
#     {
#       "dateString": "1989",
#       "label": "Time Period",
#       "type": "Info"
#     }
#   ],
#   "distributionLinks": [
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "KML Service",
#       "type": "kml",
#       "typeLabel": "KML Download",
#       "uri": "https://www.sciencebase.gov/catalogMaps/mapping/ows/5f2b00f782ceae4cb3c09708?mode=download&request=kml&service=wms&layers=MT_Stations_SanAndreasFault_LomaPrietaCA_1990"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase WMS Service",
#       "type": "serviceCapabilitiesUrl",
#       "typeLabel": "OGC Service Capabilities URL",
#       "uri": "https://www.sciencebase.gov/catalogMaps/mapping/ows/5f2b00f782ceae4cb3c09708?service=wms&request=getcapabilities&version=1.3.0"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase WFS Service",
#       "type": "serviceCapabilitiesUrl",
#       "typeLabel": "OGC Service Capabilities URL",
#       "uri": "https://www.sciencebase.gov/catalogMaps/mapping/ows/5f2b00f782ceae4cb3c09708?service=wfs&request=getcapabilities&version=1.0.0"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase Collection JSON",
#       "type": "repo",
#       "typeLabel": "ScienceBase Repository",
#       "uri": "https://www.sciencebase.gov/catalog/items?parentId=5f2b00f782ceae4cb3c09708&format=json"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase Collection ATOM",
#       "type": "repo",
#       "typeLabel": "ScienceBase Repository",
#       "uri": "https://www.sciencebase.gov/catalog/items?parentId=5f2b00f782ceae4cb3c09708&format=atom"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase Collection CSV",
#       "type": "repo",
#       "typeLabel": "ScienceBase Repository",
#       "uri": "https://www.sciencebase.gov/catalog/items?parentId=5f2b00f782ceae4cb3c09708&format=csv"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase OAI PMH Service",
#       "type": "oai-pmh",
#       "typeLabel": "OAI-PMH",
#       "uri": "https://www.sciencebase.gov/catalog/oai-pmh?verb=ListRecords&metadataPrefix=fgdc-orig&set=5f2b00f782ceae4cb3c09708"
#     },
#     {
#       "files": "",
#       "name": "",
#       "rel": "alternate",
#       "title": "ScienceBase CSW Service",
#       "type": "csw",
#       "typeLabel": "",
#       "uri": "https://www.sciencebase.gov/catalog/item/5f2b00f782ceae4cb3c09708/csw?service=CSW&version=2.0.2&request=GetRecords"
#     },
#     {
#       "files": [
#         {
#           "contentType": "text/plain",
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990/MT_Stations_SanAndreasFault_LomaPrietaCA_1990.cpg",
#           "size": 5,
#           "title": ""
#         },
#         {
#           "contentType": "application/unknown",
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990/MT_Stations_SanAndreasFault_LomaPrietaCA_1990.dbf",
#           "size": 4302,
#           "title": ""
#         },
#         {
#           "contentType": "text/plain",
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990/MT_Stations_SanAndreasFault_LomaPrietaCA_1990.prj",
#           "size": 145,
#           "title": ""
#         },
#         {
#           "contentType": "x-gis/x-shapefile",
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990/MT_Stations_SanAndreasFault_LomaPrietaCA_1990.sbn",
#           "size": 228,
#           "title": ""
#         },
#         {
#           "contentType": "x-gis/x-shapefile",
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990/MT_Stations_SanAndreasFault_LomaPrietaCA_1990.sbx",
#           "size": 124,
#           "title": ""
#         },
#         {
#           "contentType": "x-gis/x-shapefile",
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990/MT_Stations_SanAndreasFault_LomaPrietaCA_1990.shp",
#           "size": 540,
#           "title": ""
#         },
#         {
#           "contentType": "x-gis/x-shapefile",
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990/MT_Stations_SanAndreasFault_LomaPrietaCA_1990.shx",
#           "size": 180,
#           "title": ""
#         },
#         {
#           "contentType": "application/fgdc+xml",
#           "name": "Magnetotelluric-Data-from-the-San-Andreas-Fault_Loma_Prieta-CA_1989_Project-MetadataOld.xml",
#           "size": 19051,
#           "title": ""
#         }
#       ],
#       "name": "Magnetotelluric.zip",
#       "rel": "alternate",
#       "title": "Download Attached Files",
#       "type": "downloadLink",
#       "typeLabel": "Download Link",
#       "uri": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708"
#     }
#   ],
#   "facets": [
#     {
#       "boundingBox": {
#         "maxX": -121.7896389,
#         "maxY": 37.21130556,
#         "minX": -121.9026944,
#         "minY": 36.99075
#       },
#       "className": "gov.sciencebase.catalog.item.facet.ShapefileFacet",
#       "facetName": "Shapefile",
#       "files": [
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "ae3b3df9970b49b6523e608759bc957d"
#           },
#           "contentEncoding": null,
#           "contentType": "text/plain",
#           "cuid": null,
#           "dateUploaded": "2021-01-20T17:50:17Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__d5%2Fb9%2Fac%2Fd5b9ac0f326bee526f2ddc367c727aaaf331ff8b",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990.cpg",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__d5/b9/ac/d5b9ac0f326bee526f2ddc367c727aaaf331ff8b",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 5,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__d5%2Fb9%2Fac%2Fd5b9ac0f326bee526f2ddc367c727aaaf331ff8b",
#           "useForPreview": false,
#           "viewUri": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__d5%2Fb9%2Fac%2Fd5b9ac0f326bee526f2ddc367c727aaaf331ff8b&allowOpen=true"
#         },
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "9ce9af796bea228f26e20bb373c5841a"
#           },
#           "contentEncoding": null,
#           "contentType": "application/unknown",
#           "cuid": null,
#           "dateUploaded": "2021-01-20T17:50:17Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__4f%2Ff1%2F07%2F4ff107a9a6a43b0d2c8bdc8142a61f724da0653d",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990.dbf",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__4f/f1/07/4ff107a9a6a43b0d2c8bdc8142a61f724da0653d",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 4302,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__4f%2Ff1%2F07%2F4ff107a9a6a43b0d2c8bdc8142a61f724da0653d",
#           "useForPreview": false
#         },
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "c742bee3d4edfc2948a2ad08de1790a5"
#           },
#           "contentEncoding": null,
#           "contentType": "text/plain",
#           "cuid": null,
#           "dateUploaded": "2021-01-20T17:50:17Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__98%2F7b%2Fc2%2F987bc2a89c35bc977cd0fd618c41204f2f66f5e6",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990.prj",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__98/7b/c2/987bc2a89c35bc977cd0fd618c41204f2f66f5e6",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 145,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__98%2F7b%2Fc2%2F987bc2a89c35bc977cd0fd618c41204f2f66f5e6",
#           "useForPreview": false,
#           "viewUri": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__98%2F7b%2Fc2%2F987bc2a89c35bc977cd0fd618c41204f2f66f5e6&allowOpen=true"
#         },
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "ae8b2ee461fb076956cff264deabb335"
#           },
#           "contentEncoding": null,
#           "contentType": "x-gis/x-shapefile",
#           "cuid": null,
#           "dateUploaded": "2021-01-20T17:50:17Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__a7%2Fc8%2Fbd%2Fa7c8bd2073e1bb31bf77a194160ae48a1c8e95c1",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990.sbn",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__a7/c8/bd/a7c8bd2073e1bb31bf77a194160ae48a1c8e95c1",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 228,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__a7%2Fc8%2Fbd%2Fa7c8bd2073e1bb31bf77a194160ae48a1c8e95c1",
#           "useForPreview": false
#         },
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "50aec6454a1eaf42a870170f5b4e1948"
#           },
#           "contentEncoding": null,
#           "contentType": "x-gis/x-shapefile",
#           "cuid": null,
#           "dateUploaded": "2021-01-20T17:50:17Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__8d%2Fae%2F01%2F8dae01fe163c8cb38aae4c4ebadb0b8aac6b5d64",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990.sbx",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__8d/ae/01/8dae01fe163c8cb38aae4c4ebadb0b8aac6b5d64",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 124,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__8d%2Fae%2F01%2F8dae01fe163c8cb38aae4c4ebadb0b8aac6b5d64",
#           "useForPreview": false
#         },
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "da44c40a53676ee926bc497ae9c3e839"
#           },
#           "contentEncoding": null,
#           "contentType": "x-gis/x-shapefile",
#           "cuid": null,
#           "dateUploaded": "2021-01-20T17:50:17Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__be%2F24%2F4b%2Fbe244b324aacf9595b727ea48ccc118d932a897c",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990.shp",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__be/24/4b/be244b324aacf9595b727ea48ccc118d932a897c",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 540,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__be%2F24%2F4b%2Fbe244b324aacf9595b727ea48ccc118d932a897c",
#           "useForPreview": false
#         },
#         {
#           "bucket": null,
#           "checksum": {
#             "type": "MD5",
#             "value": "5258d457f28e7686abc8f91672a0fa0e"
#           },
#           "contentEncoding": null,
#           "contentType": "x-gis/x-shapefile",
#           "cuid": null,
#           "dateUploaded": "2021-01-20T17:50:17Z",
#           "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__24%2Fe4%2F6f%2F24e46f745641194f5f0044140e656351f618dd0b",
#           "imageHeight": null,
#           "imageWidth": null,
#           "key": null,
#           "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990.shx",
#           "node": null,
#           "originalMetadata": false,
#           "pathOnDisk": "__disk__24/e4/6f/24e46f745641194f5f0044140e656351f618dd0b",
#           "processToken": null,
#           "processed": false,
#           "published": null,
#           "s3Object": null,
#           "size": 180,
#           "title": "",
#           "uploadedBy": "pbrown@usgs.gov",
#           "url": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__24%2Fe4%2F6f%2F24e46f745641194f5f0044140e656351f618dd0b",
#           "useForPreview": false
#         }
#       ],
#       "geometryType": "Point",
#       "name": "MT_Stations_SanAndreasFault_LomaPrietaCA_1990",
#       "nativeCrs": "EPSG:4326"
#     }
#   ],
#   "files": [
#     {
#       "bucket": null,
#       "checksum": {
#         "type": "MD5",
#         "value": "af160683e5d88a74eae1bbe4db783dae"
#       },
#       "contentEncoding": null,
#       "contentType": "application/fgdc+xml",
#       "cuid": null,
#       "dateUploaded": "2021-02-04T19:58:47Z",
#       "downloadUri": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__b3%2Fa2%2F78%2Fb3a2787091e131ea49fcb6c6268289d689c93f16",
#       "imageHeight": null,
#       "imageWidth": null,
#       "key": null,
#       "metadataHtmlViewUri": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__b3%2Fa2%2F78%2Fb3a2787091e131ea49fcb6c6268289d689c93f16&transform=1",
#       "name": "Magnetotelluric-Data-from-the-San-Andreas-Fault_Loma_Prieta-CA_1989_Project-MetadataOld.xml",
#       "node": null,
#       "originalMetadata": true,
#       "pathOnDisk": "__disk__b3/a2/78/b3a2787091e131ea49fcb6c6268289d689c93f16",
#       "processToken": null,
#       "processed": false,
#       "published": null,
#       "s3Object": null,
#       "size": 19051,
#       "title": "",
#       "uploadedBy": "pbrown@usgs.gov",
#       "url": "https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__b3%2Fa2%2F78%2Fb3a2787091e131ea49fcb6c6268289d689c93f16",
#       "useForPreview": false
#     }
#   ],
#   "hasChildren": true,
#   "id": "5f2b00f782ceae4cb3c09708",
#   "identifiers": [
#     {
#       "key": "doi:10.5066/P9DIJHDK",
#       "scheme": "https://www.sciencebase.gov/vocab/category/item/identifier",
#       "type": "doi"
#     }
#   ],
#   "link": {
#     "rel": "self",
#     "url": "https://www.sciencebase.gov/catalog/item/5f2b00f782ceae4cb3c09708"
#   },
#   "locked": false,
#   "maintenanceUpdateFrequency": "None planned",
#   "parentId": "5f2afec982ceae4cb3c096a5",
#   "permissions": {
#     "read": {
#       "acl": [
#         "USER:abern@usgs.gov",
#         "USER:apowel19@vols.utk.edu",
#         "USER:brod@usgs.gov",
#         "USER:kenns@usgs.gov",
#         "USER:kzamudio@usgs.gov",
#         "USER:mgoldman@usgs.gov",
#         "USER:pbrown@usgs.gov",
#         "USER:tbell@usgs.gov"
#       ],
#       "inherited": false
#     },
#     "write": {
#       "acl": [
#         "USER:apowel19@vols.utk.edu",
#         "USER:brod@usgs.gov",
#         "USER:pbrown@usgs.gov",
#         "USER:sbdr_app",
#         "USER:tbell@usgs.gov"
#       ],
#       "inherited": false
#     }
#   },
#   "provenance": {
#     "createdBy": "apowel19@vols.utk.edu",
#     "dataSource": "Input directly",
#     "dateCreated": "2020-08-05T18:56:55Z",
#     "lastUpdated": "2021-02-04T19:58:48Z",
#     "lastUpdatedBy": "pbrown@usgs.gov"
#   },
#   "purpose": "The magnetotelluric data that were previously locked in an inaccessible format are now readily available as a result of open-source software. The released information could help increase understanding of the San Andreas Fault system, which runs the length of California, as well as fault systems elsewhere. Seismic activity can pose potential hazards and great risk to communities in surrounding areas. Using the framework developed in this preservation effort to make more magnetotelluric data available will deepen our knowledge of fault systems and in turn benefit public welfare.",
#   "relatedItems": {
#     "link": {
#       "rel": "related",
#       "url": "https://www.sciencebase.gov/catalog/itemLinks?itemId=5f2b00f782ceae4cb3c09708"
#     }
#   },
#   "spatial": {
#     "boundingBox": {
#       "maxX": -121.7896,
#       "maxY": 37.2113,
#       "minX": -121.9027,
#       "minY": 36.9907
#     }
#   },
#   "summary": "The U.S. Geological Survey (USGS) Geology, Geophysics and Geochemistry Science Center (GGGSC) collaborated with the USGS Science Analytics and Synthesis (SAS) team to preserve and release a subset of magnetotelluric data from the San Andreas Fault in Loma Prieta, California. The San Andreas Fault data were collected by the Branch of Geophysics, a precursor to the now GGGSC, between 1989 and 1994. The magnetotelluric data selected for this preservation project were collected in 1989 using USGS portable truck mounted systems that measure the distribution of electrical conductivity beneath the surface of the earth. Truck mounted systems of this era output data to 3.5\u201d discs, from which data were recovered and transformed to binary or [...]",
#   "systemTypes": [
#     "Folder",
#     "Downloadable",
#     "Mappable"
#   ],
#   "tags": [
#     {
#       "name": "geophysics",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "San Andreas Fault System",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "electromagnetic surveying",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "faulting (geologic)",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "magnetotelluric surveying",
#       "scheme": "USGS Thesaurus",
#       "type": "Theme"
#     },
#     {
#       "name": "geoscientificInformation",
#       "scheme": "ISO 19115 Topic Category",
#       "type": "Theme"
#     },
#     {
#       "name": "Electrical Data Interchange",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "EDI",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "Searchable Product Depository",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "SPUD",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "legacy data",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "magnetotelluric sounding",
#       "scheme": "None",
#       "type": "Theme"
#     },
#     {
#       "name": "OGC WMS Service",
#       "scheme": "Types",
#       "type": "Theme"
#     },
#     {
#       "name": "Map Service",
#       "scheme": "Types",
#       "type": "Theme"
#     },
#     {
#       "name": "OGC WFS Layer",
#       "scheme": "Types",
#       "type": "Theme"
#     },
#     {
#       "name": "OGC WMS Layer",
#       "scheme": "Types",
#       "type": "Theme"
#     },
#     {
#       "name": "United States",
#       "scheme": "Common Geographic Areas",
#       "type": "Theme"
#     },
#     {
#       "name": "California",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Monterey County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Loma Prieta",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "San Andreas Fault",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     },
#     {
#       "name": "Fresno County",
#       "scheme": "Geographic Names Information System (GNIS)",
#       "type": "Place"
#     }
#   ],
#   "title": "Magnetotelluric Data from the San Andreas Fault, Loma Prieta CA, 1989",
#   "webLinks": [
#     {
#       "hidden": false,
#       "rel": "related",
#       "type": "Online Link",
#       "uri": "https://doi.org/10.5066/P9DIJHDK"
#     },
#     {
#       "hidden": false,
#       "rel": "related",
#       "title": "Digital Data",
#       "type": "webLink",
#       "uri": "https://doi.org/10.5066/P9DIJHDK"
#     }
#   ]
# }

# %%
#List the XML files ScienceBase:
arrayDownloadUri = []
arrayName = []
for item in item_json['files']:
    arrayName.append(item['name'])
    arrayDownloadUri.append(item['downloadUri']) #downloadUri
    

for i in range(len(arrayName)): 
 print ('Name Index ' + str(i) + ': ' + arrayName[i])
 print ('URL Index ' + str(i) + ': ' + arrayDownloadUri[i] + '\n')
# Out:
# Name Index 0: Magnetotelluric-Data-from-the-San-Andreas-Fault_Loma_Prieta-CA_1989_Project-MetadataOld.xml
# URL Index 0: https://www.sciencebase.gov/catalog/file/get/5f2b00f782ceae4cb3c09708?f=__disk__b3%2Fa2%2F78%2Fb3a2787091e131ea49fcb6c6268289d689c93f16

# %%
#Load the metadata file - be sure to use the correct URL below
#downloadUri = 'https://www.sciencebase.gov/catalog/file/get/5f066e2682ce21d4c3f90237?f=__disk__63%2F64%2F80%2F63648082412369fa65285e35e8487e08f5db696c'#item['downloadUri']
#print (arrayDownloadUri[0])
from urllib.request import urlopen
from xml.etree.ElementTree import parse

#This is how we get the item using a url - we have to use the sb-py command for SB objects that are not yet public
#var_url = urlopen(arrayDownloadUri[0])
#root = parse(var_url)

SBmetadata=sb.get(arrayDownloadUri[0])#Here is where one can change the index pointing to different URL values printed above
SBmetadata = SBmetadata.split('\n', 1)[-1]#remove first UTF encoding line, this messes up the etree parse
#print (SBmetadata) 

root = etree.fromstring(SBmetadata) # parse metadata using etree from a string instead of from a file like above
root
# Out:
# <Element metadata at 0x248fc2b6a08>

# %%
#Now let's replace a section using xtree followed by a find and replace example.
for descript in root.iter('descript'):
 abstract = descript.find('abstract')
 print (abstract.text)
# Out:
# New Text3

# %%
#now replace the abstract text
abstract.text='Slackmaster Felipe Cafe'
#Now Check Replacement
for descript in root.iter('descript'):
 abstract = descript.find('abstract')
 print (abstract.text)
# Out:
# Slackmaster Felipe Cafe

# %%
#Now Overwrite metadata on ScienceBase
#https://stackoverflow.com/questions/15634580/lxml-etree-element-object-has-no-attribute-write-python
#etree.tostring(root, encoding='utf-8', xml_declaration=True) 
#print(root

# %%
#Write Etree to XML String
strXMLout = etree.tostring(root, encoding='unicode')
#Now add that silly Unicode line
strXMLout = '<?xml version=\'1.0\' encoding=\'UTF-8\'?>\n' + strXMLout  #Ahhh use \ to escape out those damn single quotes
strXMLout
# Out:
# '<?xml version=\'1.0\' encoding=\'UTF-8\'?>\n<metadata>\n  <idinfo>\n    <citation>\n      <citeinfo>\n        <origin>Brian D. Rodriguez</origin>\n        <origin>Michaela R. Johnson</origin>\n        <origin>Ricardo McClees-Funinan</origin>\n        <origin>Shafer Powell</origin>\n        <origin>Kyle D. Enns</origin>\n        <pubdate>2020</pubdate>\n        <title>Magnetotelluric Data from the San Andreas Fault, Loma Prieta CA, 1989</title>\n        <geoform>magnetotelluric data</geoform>\n        <onlink>https://doi.org/10.5066/P9DIJHDK</onlink>\n      </citeinfo>\n    </citation>\n    <descript>\n      <abstract>Slackmaster Felipe Cafe</abstract>\n      <purpose>The magnetotelluric data that were previously locked in an inaccessible format are now readily available as a result of open-source software. The released information could help increase understanding of the San Andreas Fault system, which runs the length of California, as well as fault systems elsewhere. Seismic activity can pose potential hazards and great risk to communities in surrounding areas. Using the framework developed in this preservation effort to make more magnetotelluric data available will deepen our knowledge of fault systems and in turn benefit public welfare.</purpose>\n      <supplinf>Each station in the overall survey was taken at a single point. While the MT files are not in vector format all measurements are referenced to the location of the station. There were 10 site locations surveyed for this particular study. At the time of data collection surveyors received oral permission from landowners of each site to conduct magnetotelluric surveys on the land. The landowners from 1989 may or may not have changed. Potential site locations that did not receive oral permission from landowners were not surveyed and alternate sites were pursued instead. This adjustment affected the spatial distribution of the survey station locations. The site location points plotted in the shapefile are considered estimates, see horizontal accuracy report below for more details.</supplinf>\n    </descript>\n    <timeperd>\n      <timeinfo>\n        <sngdate>\n          <caldate>1989</caldate>\n        </sngdate>\n      </timeinfo>\n      <current>observed</current>\n    </timeperd>\n    <status>\n      <progress>Complete</progress>\n      <update>None planned</update>\n    </status>\n    <spdom>\n      <descgeog>The shapefile plots the locations of the 10 sites where magnetotelluric surveys were conducted along the San Andreas Fault in Loma Prieta, CA in 1989.</descgeog>\n      <bounding>\n        <westbc>-121.9027</westbc>\n        <eastbc>-121.7896</eastbc>\n        <northbc>37.2113</northbc>\n        <southbc>36.9907</southbc>\n      </bounding>\n    </spdom>\n    <keywords>\n      <theme>\n        <themekt>USGS Thesaurus</themekt>\n        <themekey>geophysics</themekey>\n        <themekey>San Andreas Fault System</themekey>\n        <themekey>electromagnetic surveying</themekey>\n        <themekey>faulting (geologic)</themekey>\n        <themekey>magnetotelluric surveying</themekey>\n      </theme>\n      <theme>\n        <themekt>ISO 19115 Topic Category</themekt>\n        <themekey>geoscientificInformation</themekey>\n      </theme>\n      <theme>\n        <themekt>None</themekt>\n        <themekey>Electrical Data Interchange</themekey>\n        <themekey>EDI</themekey>\n        <themekey>Searchable Product Depository</themekey>\n        <themekey>SPUD</themekey>\n        <themekey>legacy data</themekey>\n        <themekey>magnetotelluric sounding</themekey>\n      </theme>\n      <theme>\n        <themekt>Types</themekt>\n        <themekey>OGC WMS Service</themekey>\n        <themekey>Map Service</themekey>\n        <themekey>OGC WFS Layer</themekey>\n        <themekey>OGC WMS Layer</themekey>\n      </theme>\n      <theme>\n        <themekt>Common Geographic Areas</themekt>\n        <themekey>United States</themekey>\n      </theme>\n      <place>\n        <p ...

# %%
WorkingPath = r"C:\CurrentWork\DataReleases\Loma1989\Test"
WorkingFileName = arrayName[0]
WorkingPathAndFile = WorkingPath + "\\" + WorkingFileName
print ('The MT Data Path is: ' + '"' + WorkingPathAndFile + '"')
# Out:
# The MT Data Path is: "C:\CurrentWork\DataReleases\Loma1989\Test\Magnetotelluric-Data-from-the-San-Andreas-Fault_Loma_Prieta-CA_1989_Project-MetadataOld.xml"

# %%
#Now write this new string to ScienceBase
#First output string to a file
XMLFileFinal = open(WorkingPathAndFile,"w+")
XMLFileFinal.write(strXMLout)
XMLFileFinal.close()

# Define item somehow? arrayDownloadUri[0]
#item = sb.get_item(item_id)

#strXMLout = sb.update_item(arrayDownloadUri[0])

# %%
sb.replace_file(WorkingPathAndFile, item_json)
